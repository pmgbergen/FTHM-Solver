# %%
import numpy as np
from matplotlib import pyplot as plt

a = lambda n0, n1: np.sqrt((n0 - 5) ** 2 + n1 ** 2)
b = lambda n0, n1: np.sqrt((n1 - 8) ** 2 + n0 ** 2)
func = lambda n0, n1: a(n0, n1) + b(n0, n1) - np.sqrt(a(n0, n1) ** 2 + b(n0, n1) ** 2)
# func = lambda n0, n1: a(n0, n1) * b(n0, n1)

xrange = np.linspace(-10, 10, 1000)
yrange = np.linspace(-10, 10, 1000)
X, Y = np.meshgrid(xrange, yrange, indexing='ij')

plt.pcolormesh(X, Y, func(X, Y), norm='log')
plt.colorbar()

# %% [markdown]
# a >= 0
# b >= 0
# a * b = 0
#
# a = (n1 - 56) ** 2
# b = (n2 - 8) ** 2
#
# a + b - sqrt(a^2 + b^2)
